# %%
#dans jupyter lab
import requests
import json

# URL de ton API FastAPI
url = "http://localhost:8000/predict"

# Données à envoyer
data = {
    "CreditScore": 650,
    "Age": 35,
    "Tenure": 5,
    "Balance": 50000,
    "NumOfProducts": 2,
    "HasCrCard": 1,
    "IsActiveMember": 1,
    "EstimatedSalary": 75000,
    "Geography_Germany": 0,
    "Geography_Spain": 1
}

# Envoyer la requête POST
response = requests.post(url, json=data)

# Afficher la réponse
print(f"Status Code: {response.status_code}")
print(f"Response: {response.json()}")
# Out:
# Status Code: 200
# Response: {'churn_probability': 0.0036, 'prediction': 0, 'risk_level': 'Low'}

# %% [markdown]
# # apret Récupération de l'URL et Test Final
# ## Utilise ton Jupyter Lab pour faire le test final :

# %%
import requests

# REMPLACE CETTE URL PAR LA TIENNE
url = "https://bank-churn.votre-id.swedencentral.azurecontainerapps.io/predict"

data = {
    "CreditScore": 650, "Age": 35, "Tenure": 5, "Balance": 50000,
    "NumOfProducts": 2, "HasCrCard": 1, "IsActiveMember": 1,
    "EstimatedSalary": 75000, "Geography_Germany": 0, "Geography_Spain": 1
}

response = requests.post(url, json=data)
print(f"Status: {response.status_code}")
print(f"Prediction: {response.json()}")
